# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuSingh000/NamasteQuantum/blob/main/Mathematics_%20For_Quantum/Vectors_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1️⃣ Vectors — The Core of Quantum States
#
# ### Intuition
# - A vector is **just a direction + magnitude**.
# - Think of it as an **arrow in space**.
#
# - In quantum computing, a **single qubit** is a vector in a 2-dimensional complex space:
#
# $$
# |\psi\rangle = \alpha |0\rangle + \beta |1\rangle
# $$
#
# - Here:
#   - $|0\rangle$ and $|1\rangle$ are the **basis vectors** (like axes in 2D space). Any qubit state can be written as a combination of |0⟩ and |1⟩:
#   - $\alpha$ and $\beta$ are **complex numbers** called amplitudes, telling how much the vector points along each axis.
#
# ---
#
# ### Example: Physical Intuition
# - Walk 3 steps **north** → vector $v_1 = (0,3)$
# - Walk 4 steps **east** → vector $v_2 = (4,0)$
#
# Combine them tip-to-tip:
#
# $$
# v_1 + v_2 = (0+4, 3+0) = (4,3)
# $$
#
# This is like **superposition in quantum computing**: multiple directions combined.
#
# ---
#
# ### Numerical Example
# - Vector A = (2,1)
# - Vector B = (-1,3)
#
# Linear combination: $3A - 2B$
#
# $$
# 3(2,1) - 2(-1,3) = (6,3) - (-2,6) = (6,3) + (2,-6) = (8,-3)
# $$
#
# - **Tip:** Quantum operations also **scale and combine vectors**, but usually with complex numbers.
#
# ---
#
# ### Key Idea for Quantum Computing
# - **Qubit = vector in 2D complex space**
# - **n qubits = a system that can be in $2^n$ different states at the same time**
#
# **Example:**
# - 1 qubit → 2 states: |0⟩, |1⟩
# - 2 qubits → 4 states: |00⟩, |01⟩, |10⟩, |11⟩
# - 3 qubits → 8 states: |000⟩, |001⟩, … , |111⟩
#
# Superposition allows the system to **exist in all these states simultaneously**.
#
# - **Superposition = adding different “directions” together**
# A qubit can **point partly toward |0⟩ and partly toward |1⟩ at the same time**.
#
# **Example:**
# $$
# |\psi\rangle = \frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle
# $$
# This means the qubit is **equally likely to be measured as 0 or 1**.
#
# - **Normalization = total probability = 1**
# The qubit’s amplitudes must satisfy:
# $$
# |\alpha|^2 + |\beta|^2 = 1
# $$
#
# Intuition: Think of the qubit as an **arrow that must stay on the “unit circle”** so that probabilities make sense.
# - $|\alpha|^2$ = probability of measuring 0
# - $|\beta|^2$ = probability of measuring 1

# %% [markdown]
# ## Why “Both 0 and 1” Doesn’t Increase the Number of States
#
# Think of directions in space
#
# Imagine you are in a room with only two walls: north and east.
#
# You can walk north (|0⟩) or east (|1⟩).
#
# If you walk part north and part east at the same time, you are diagonally in the room.
#
# Even though you can go diagonal, you are still in the same 2D room.
#
# You are not creating a new wall — just moving along a combination of the two directions.
#
# Now for 2 qubits (4-dimensional space)
#
# Two qubits = 4 basis directions: |00⟩, |01⟩, |10⟩, |11⟩
#
# Any “superposition” = like moving somewhere inside a 4D box, along some combination of the corners.
#
# Analogy:
#
# Corner	Meaning
# 	00⟩
# 	01⟩
# 	10⟩
# 	11⟩
#
# If you take a superposition like ( |00⟩ + |01⟩ ) / √2, it’s like being halfway between two corners.
#
# You are not creating a 5th corner — just pointing somewhere along the line connecting existing corners.
